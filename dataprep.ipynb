# %%
import numpy as np
import pandas as pd
from tmdbv3api import TMDb, Movie
tmdb = TMDb()

# %%
df = pd.read_csv('./TMDB_movie_dataset_v11.csv')
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
features = ['id', 'title', 'vote_average', 'revenue', 'genres', 'release_date']
filtered_df = df[features]
filtered_df.head()
# Out:
#        id            title  vote_average     revenue  \
# 0   27205        Inception         8.364   825532764
# 1  157336     Interstellar         8.417   701729206
# 2     155  The Dark Knight         8.512  1004558444
# 3   19995           Avatar         7.573  2923706026
# 4   24428     The Avengers         7.710  1518815515
#
#                                         genres release_date
# 0           Action, Science Fiction, Adventure   2010-07-15
# 1            Adventure, Drama, Science Fiction   2014-11-05
# 2               Drama, Action, Crime, Thriller   2008-07-16
# 3  Action, Adventure, Fantasy, Science Fiction   2009-12-15
# 4           Science Fiction, Action, Adventure   2012-04-25

# %%
filtered_df.dropna(how = 'any', inplace=True)
filtered_df['year'] = filtered_df['release_date'].str[:4]
filtered_df['year'] = filtered_df['year'].astype('int64')
filtered_df.head()
# Out:
# /var/folders/qn/18wdgjxd7pq9_v70cxrqmfyh0000gn/T/ipykernel_54843/222802839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.dropna(how = 'any', inplace=True)
# /var/folders/qn/18wdgjxd7pq9_v70cxrqmfyh0000gn/T/ipykernel_54843/222802839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['year'] = filtered_df['release_date'].str[:4]
# /var/folders/qn/18wdgjxd7pq9_v70cxrqmfyh0000gn/T/ipykernel_54843/222802839.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filtered_df.shape
# Out:
# (629573, 7)

# %%
filtered_df = filtered_df[(filtered_df['year'] > 2010) & (filtered_df['year'] < 2025)]

# %%
filtered_df.isna().sum()
# Out:
# id              0
# title           0
# vote_average    0
# revenue         0
# genres          0
# release_date    0
# year            0
# dtype: int64

# %%
new_df = filtered_df[(filtered_df['vote_average'] > 0) & (filtered_df['revenue'] > 100)]
new_df = new_df.reset_index(drop = True)

# %%
new_df
# Out:
#           id                                              title  vote_average  \
# 0     157336                                       Interstellar         8.417
# 1      24428                                       The Avengers         7.710
# 2     293660                                           Deadpool         7.606
# 3     299536                             Avengers: Infinity War         8.255
# 4     118340                            Guardians of the Galaxy         7.906
# ...      ...                                                ...           ...
# 6583  427036                                   A Family On Edge         7.000
# 6584  416280                                      Kamen Rider 1         6.000
# 6585  436104  Kamen Rider Ghost: The 100 Eyecons and Ghost’s...         7.000
# 6586  429674                                 Oye Kuch Kar Guzar        10.000
# 6587  383008                                                 真爱         8.000
#
# ...

# %%
import requests

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5YTBhYmZkNTJiYjZjMjkwYzVjMTIzZDZiNjlkODNjYiIsIm5iZiI6MTcyOTM1MzA2NS44MTA5MTgsInN1YiI6IjY2ZjI3NWU0YTgyYjAwNTcwMzI2ZDIxZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.k1dQkNkB_2phSel35QLQSzoz98UoBve1fMRzHJyESKk"
}

def get_director_cast(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=en-US"
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        data = response.json()
        # Get the first three cast members
        cast_names = [cast['name'] for cast in data['cast'][:3]]
        # Fill with None if less than three actors
        cast_names += [None] * (3 - len(cast_names))
        
        # Get the director from the crew
        director = next((crew['name'] for crew in data['crew'] if crew['job'] == 'Director'), None)
        
        result = cast_names + [director]
        print(result)
        return result
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for movie ID {movie_id}: {e}")
        return [None, None, None, None]

# Apply the function to the DataFrame
new_df[['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name']] = new_df['id'].apply(get_director_cast).apply(pd.Series)
# Out:
# ['Matthew McConaughey', 'Anne Hathaway', 'Michael Caine', 'Christopher Nolan']
# ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Joss Whedon']
# ['Ryan Reynolds', 'Morena Baccarin', 'Ed Skrein', 'Tim Miller']
# ['Robert Downey Jr.', 'Chris Evans', 'Chris Hemsworth', 'Joe Russo']
# ['Chris Pratt', 'Zoe Saldaña', 'Dave Bautista', 'James Gunn']
# ['Jamie Foxx', 'Christoph Waltz', 'Leonardo DiCaprio', 'Quentin Tarantino']
# ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Anthony Russo']
# ['Joaquin Phoenix', 'Robert De Niro', 'Zazie Beetz', 'Todd Phillips']
# ['Leonardo DiCaprio', 'Jonah Hill', 'Margot Robbie', 'Martin Scorsese']
# ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Joss Whedon']
# ['Chris Evans', 'Robert Downey Jr.', 'Scarlett Johansson', 'Joe Russo']
# ['Christian Bale', 'Gary Oldman', 'Tom Hardy', 'Christopher Nolan']
# ['Robert Downey Jr.', 'Gwyneth Paltrow', 'Don Cheadle', 'Shane Black']
# ...

# %%
new_df
# Out:
#           id                                              title  vote_average  \
# 0     157336                                       Interstellar         8.417
# 1      24428                                       The Avengers         7.710
# 2     293660                                           Deadpool         7.606
# 3     299536                             Avengers: Infinity War         8.255
# 4     118340                            Guardians of the Galaxy         7.906
# ...      ...                                                ...           ...
# 6583  427036                                   A Family On Edge         7.000
# 6584  416280                                      Kamen Rider 1         6.000
# 6585  436104  Kamen Rider Ghost: The 100 Eyecons and Ghost’s...         7.000
# 6586  429674                                 Oye Kuch Kar Guzar        10.000
# 6587  383008                                                 真爱         8.000
#
# ...

# %%
new_df['comb'] = new_df['actor_1_name'].str.lower() + " " + new_df['actor_2_name'].str.lower() + ", " + new_df['actor_3_name'].str.lower() + ", " + new_df['director_name'].str.lower()

# %%
new_df
# Out:
#           id                                              title  vote_average  \
# 0     157336                                       Interstellar         8.417
# 1      24428                                       The Avengers         7.710
# 2     293660                                           Deadpool         7.606
# 3     299536                             Avengers: Infinity War         8.255
# 4     118340                            Guardians of the Galaxy         7.906
# ...      ...                                                ...           ...
# 6583  427036                                   A Family On Edge         7.000
# 6584  416280                                      Kamen Rider 1         6.000
# 6585  436104  Kamen Rider Ghost: The 100 Eyecons and Ghost’s...         7.000
# 6586  429674                                 Oye Kuch Kar Guzar        10.000
# 6587  383008                                                 真爱         8.000
#
# ...

# %%
new_df.to_csv('final_data.csv')
